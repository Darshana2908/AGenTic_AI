# %% [markdown]
# ## Section 1
# ##### Source : https://www.youtube.com/watch?v=vr_sJ4veYOY
#
# ##### 1. Get Your Claude API Key
# ###### You can get a Claude API key by signing up on Anthropic's developer platform:
#
# ###### Go to: https://console.anthropic.com
#
# ###### Sign up or log in.
#
# ###### Navigate to API Keys from the dashboard (left bottom).
#
# ###### Click "Create Key", and copy the generated key.
#
# ##### 2. Store the API Key Securely
# ###### Use a .env file to securely store the API key in your project directory.
#
# ###### Steps:
# ###### Create a file in your root project directory named .env.
#
# ###### Add the following line to that .env file:
# ###### ANTHROPIC_API_KEY=your_claude_api_key_here
#
# ###### Replace your_claude_api_key_here with the actual key from the Claude dashboard.

# %%
pip install llama-index

# %%
pip install llama-index-llms-anthropic

# %%
import os
import sys

path_to_add = r"C:\Users\darsh\AppData\Roaming\Python\Python312\Scripts"
if path_to_add not in os.environ["PATH"]:
    os.environ["PATH"] += os.pathsep + path_to_add
    sys.path.append(path_to_add)

print("Path added!")

# %%
pip install --upgrade llama-index #Upgraded as i was getting the error as CodeInterpreterToolSpec not found

# %%
pip install --upgrade llama-index-llms-anthropic #Upgraded as i was getting the error as CodeInterpreterToolSpec not found

# %%
from llama_index.tools.code_interpreter.base import CodeInterpreterToolSpec #Checking to see if this module was installed

# %%
##This version doesnt work - given only for explanation

#Imports
from llama_index.llms.anthropic import Anthropic
from llama_index.core import Settings
from llama_index.tools.code_interpreter.base import CodeInterpreterToolSpec
from llama_index.core.tools import FunctionTool
from llama_index.core.agent import FunctionCallingAgent
from dotenv import load_dotenv
import os
import yfinance as yf
load_dotenv()

## Note: I get error here :
## ---------------------------------------------------------------------------
## ModuleNotFoundError                       Traceback (most recent call last)
## Cell In[3], line 1
## ----> 1 from llama_index.tools.code_interpreter.base import CodeInterpreterToolSpec

## ModuleNotFoundError: No module named 'llama_index.tools'

## Reason: I found that the module doesn't exist in the latest public version of llama-index. It was either:
## Part of a private/internal demo
## Or hasn't yet been released to public packages

#Code Interpretor
code_spec = CodeInterpreterToolSpec()
tools = code_spec.to_tool_list()

#Tokenizer and calling the claude
tokenizer = Anthropic().tokenizer
Settings.tokenizer = tokenizer

llm_claude = Anthropic(model="claude-3-5-sonnet-20241022")

#Define our agent
agent = FunctionCallingAgent.from_tools(
    tools,
    llm=llm_claude,
    verbose=True,
    allow_parallel_tool_calls=False,
)

#Define the prompt
ticker = "PLTR"

prompt = f"""
Write Python code to:
- Detect which date is today
- Based on this date, fetch historical prices of {ticker} from the beginning of the month until today.
- Analyze the last month prices
"""

#Run the agent
resp = agent.chat(prompt)

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-0.2.63-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\darsh\appdata\roaming\python\python312\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 1.9 MB/s eta 0:00:02
#      ------------- -------------------------- 1.0/3.0 MB 2.0 MB/s eta 0:00:01
#      -------------------- ------------------- 1.6/3.0 MB 2.3 MB/s eta 0:00:01
#      --------------------------- ------------ 2.1/3.0 MB 2.3 MB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 2.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.11.3-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\programdata\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\programdata\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-0.2.63-py2.py3-none-any.whl (118 kB)
# Downloading curl_cffi-0.11.3-cp39-abi3-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.4 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.9 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139097 sha256=57f521eeb8075888b69dd3a52c880fd651d54510784f14d54cee3f7e188b12f8
#   Stored in directory: c:\users\darsh\appdata\local\pip\cache\wheels\1a\57\6a\bb71346381d0d911cd4ce3026f1fa720da76707e4f01cf27dd
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, curl_cffi, yfinance
# Successfully installed curl_cffi-0.11.3 multitasking-0.0.11 peewee-3.18.1 websockets-15.0.1 yfinance-0.2.63

# %%
#Imports
from llama_index.llms.anthropic import Anthropic
from llama_index.core import Settings
from llama_index.core.agent import FunctionCallingAgent
from llama_index.core.tools import FunctionTool
from dotenv import load_dotenv
import yfinance as yf
import datetime
import os

#Load the env file
load_dotenv()

#Define a function to interpret code dynamically
def run_code(prompt: str) -> str:
    # Replace this with a secure sandbox in production!
    local_vars = {}
    try:
        exec(prompt, {"yf": yf, "datetime": datetime}, local_vars)
        return str(local_vars)
    except Exception as e:
        return f"Error: {e}"

#Wrap it in a FunctionTool
code_tool = FunctionTool.from_defaults(fn=run_code)

#Set up Claude
llm_claude = Anthropic(model="claude-3-sonnet-20240229")
Settings.llm = llm_claude

#Define the agent
agent = FunctionCallingAgent.from_tools(
    tools=[code_tool],
    llm=llm_claude,
    verbose=True,
    allow_parallel_tool_calls=False,
)

#Ask the agent to run Python code
ticker = "PLTR"
prompt = f"""
Write and execute Python code to:
- Detect today's date
- Fetch historical prices of {ticker} from the beginning of the current month until today using yfinance
- Analyze the price trend over the month
Return a summary of your findings.
"""

#Run the agent
response = agent.chat(prompt)
print(response)
# Out:
# > Running step da39f123-e554-4cc5-87fa-d87dadcbf60d. Step input:
# Write and execute Python code to:
# - Detect today's date
# - Fetch historical prices of PLTR from the beginning of the current month until today using yfinance
# - Analyze the price trend over the month
# Return a summary of your findings.
#
# Added user message to memory:
# Write and execute Python code to:
# - Detect today's date
# - Fetch historical prices of PLTR from the beginning of the current month until today using yfinance
# - Analyze the price trend over the month
# Return a summary of your findings.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[3], line 50
#      41 prompt = f"""
#      42 Write and execute Python code to:
#      43 - Detect today's date
#    (...)
#      46 Return a summary of your findings.
#      47 """
#      49 #Run the agent
# ---> 50 response = agent.chat(prompt)
#      51 print(response)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\instrumentation\dispatcher.py:323, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     320             _logger.debug(f"Failed to reset active_span_id: {e}")
#     322 try:
# --> 323     result = func(*args, **kwargs)
#     324     if isinstance(result, asyncio.Future):
#     325         # If the result is a Future, wrap it
#     326         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\callbacks\utils.py:42, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      40 callback_manager = cast(CallbackManager, callback_manager)
#      41 with callback_manager.as_trace(trace_id):
# ---> 42     return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\agent\runner\base.py:695, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     690     tool_choice = self.default_tool_choice
#     691 with self.callback_manager.event(
#     692     CBEventType.AGENT_STEP,
#     693     payload={EventPayload.MESSAGES: [message]},
#     694 ) as e:
# --> 695     chat_response = self._chat(
#     696         message=message,
#     697         chat_history=chat_history,
#     698         tool_choice=tool_choice,
#     699         mode=ChatResponseMode.WAIT,
#     700     )
#     701     assert isinstance(chat_response, AgentChatResponse)
#     702     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\instrumentation\dispatcher.py:323, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     320             _logger.debug(f"Failed to reset active_span_id: {e}")
#     322 try:
# --> 323     result = func(*args, **kwargs)
#     324     if isinstance(result, asyncio.Future):
#     325         # If the result is a Future, wrap it
#     326         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\agent\runner\base.py:627, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     624 dispatcher.event(AgentChatWithStepStartEvent(user_msg=message))
#     625 while True:
#     626     # pass step queue in as argument, assume step executor is stateless
# --> 627     cur_step_output = self._run_step(
#     628         task.task_id, mode=mode, tool_choice=tool_choice
#     629     )
#     631     if cur_step_output.is_last:
#     632         result_output = cur_step_output
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\instrumentation\dispatcher.py:323, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     320             _logger.debug(f"Failed to reset active_span_id: {e}")
#     322 try:
# --> 323     result = func(*args, **kwargs)
#     324     if isinstance(result, asyncio.Future):
#     325         # If the result is a Future, wrap it
#     326         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\agent\runner\base.py:423, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     419 # TODO: figure out if you can dynamically swap in different step executors
#     420 # not clear when you would do that by theoretically possible
#     422 if mode == ChatResponseMode.WAIT:
# --> 423     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     424 elif mode == ChatResponseMode.STREAM:
#     425     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\instrumentation\dispatcher.py:323, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     320             _logger.debug(f"Failed to reset active_span_id: {e}")
#     322 try:
# --> 323     result = func(*args, **kwargs)
#     324     if isinstance(result, asyncio.Future):
#     325         # If the result is a Future, wrap it
#     326         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\callbacks\utils.py:42, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      40 callback_manager = cast(CallbackManager, callback_manager)
#      41 with callback_manager.as_trace(trace_id):
# ---> 42     return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\agent\function_calling\step.py:309, in FunctionCallingAgentWorker.run_step(self, step, task, **kwargs)
#     306 tools = self.get_tools(task.input)
#     308 # get response and tool call (if exists)
# --> 309 response = self._llm.chat_with_tools(
#     310     tools=tools,
#     311     user_msg=None,
#     312     chat_history=self.get_all_messages(task),
#     313     verbose=self._verbose,
#     314     allow_parallel_tool_calls=self.allow_parallel_tool_calls,
#     315 )
#     316 tool_calls = self._llm.get_tool_calls_from_response(
#     317     response, error_on_no_tool_call=False
#     318 )
#     319 tool_outputs: List[ToolOutput] = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\llms\function_calling.py:55, in FunctionCallingLLM.chat_with_tools(self, tools, user_msg, chat_history, verbose, allow_parallel_tool_calls, tool_required, **kwargs)
#      45 """Chat with function calling."""
#      46 chat_kwargs = self._prepare_chat_with_tools_compat(
#      47     tools,
#      48     user_msg=user_msg,
#    (...)
#      53     **kwargs,
#      54 )
# ---> 55 response = self.chat(**chat_kwargs)
#      56 return self._validate_chat_with_tools_response(
#      57     response,
#      58     tools,
#      59     allow_parallel_tool_calls=allow_parallel_tool_calls,
#      60     **kwargs,
#      61 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\instrumentation\dispatcher.py:323, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     320             _logger.debug(f"Failed to reset active_span_id: {e}")
#     322 try:
# --> 323     result = func(*args, **kwargs)
#     324     if isinstance(result, asyncio.Future):
#     325         # If the result is a Future, wrap it
#     326         new_future = asyncio.ensure_future(result)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\core\llms\callbacks.py:175, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     166 event_id = callback_manager.on_event_start(
#     167     CBEventType.LLM,
#     168     payload={
#    (...)
#     172     },
#     173 )
#     174 try:
# --> 175     f_return_val = f(_self, messages, **kwargs)
#     176 except BaseException as e:
#     177     callback_manager.on_event_end(
#     178         CBEventType.LLM,
#     179         payload={EventPayload.EXCEPTION: e},
#     180         event_id=event_id,
#     181     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\llama_index\llms\anthropic\base.py:361, in Anthropic.chat(self, messages, **kwargs)
#     356 anthropic_messages, system_prompt = messages_to_anthropic_messages(
#     357     messages, self.cache_idx
#     358 )
#     359 all_kwargs = self._get_all_kwargs(**kwargs)
# --> 361 response = self._client.messages.create(
#     362     messages=anthropic_messages,
#     363     stream=False,
#     364     system=system_prompt,
#     365     **all_kwargs,
#     366 )
#     368 content, tool_calls, thinking, citations = (
#     369     self._get_content_and_tool_calls_and_thinking(response)
#     370 )
#     372 return AnthropicChatResponse(
#     373     message=ChatMessage(
#     374         role=MessageRole.ASSISTANT,
#    (...)
#     382     raw=dict(response),
#     383 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\anthropic\_utils\_utils.py:283, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     281             msg = f"Missing required argument: {quote(missing[0])}"
#     282     raise TypeError(msg)
# --> 283 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\anthropic\resources\messages\messages.py:978, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     971 if model in DEPRECATED_MODELS:
#     972     warnings.warn(
#     973         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     974         DeprecationWarning,
#     975         stacklevel=3,
#     976     )
# --> 978 return self._post(
#     979     "/v1/messages",
#     980     body=maybe_transform(
#     981         {
#     982             "max_tokens": max_tokens,
#     983             "messages": messages,
#     984             "model": model,
#     985             "metadata": metadata,
#     986             "service_tier": service_tier,
#     987             "stop_sequences": stop_sequences,
#     988             "stream": stream,
#     989             "system": system,
#     990             "temperature": temperature,
#     991             "thinking": thinking,
#     992             "tool_choice": tool_choice,
#     993             "tools": tools,
#     994             "top_k": top_k,
#     995             "top_p": top_p,
#     996         },
#     997         message_create_params.MessageCreateParamsStreaming
#     998         if stream
#     999         else message_create_params.MessageCreateParamsNonStreaming,
#    1000     ),
#    1001     options=make_request_options(
#    1002         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1003     ),
#    1004     cast_to=Message,
#    1005     stream=stream or False,
#    1006     stream_cls=Stream[RawMessageStreamEvent],
#    1007 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\anthropic\_base_client.py:1307, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1293 def post(
#    1294     self,
#    1295     path: str,
#    (...)
#    1302     stream_cls: type[_StreamT] | None = None,
#    1303 ) -> ResponseT | _StreamT:
#    1304     opts = FinalRequestOptions.construct(
#    1305         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1306     )
# -> 1307     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\anthropic\_base_client.py:1102, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1099             err.response.read()
#    1101         log.debug("Re-raising status error")
# -> 1102         raise self._make_status_error_from_response(err.response) from None
#    1104     break
#    1106 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}}

# %%
https://console.anthropic.com/settings/billing
